# %% [markdown]
# <h3>Tópicos em Big Data: Brazzilian tweets about Covid 19 </h3>

# %%
import numpy as np
import nltk
import pandas as pd
import matplotlib.pyplot as plt
from csv import reader

nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import WhitespaceTokenizer 
from nltk.probability import FreqDist
from nltk.tokenize import blankline_tokenize
## Simple WordCloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\marnes.simao.cassule\AppData\Roaming\nltk_dat
# [nltk_data]     a...
# [nltk_data]   Package punkt is already up-to-date!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-56491e9a0db6> in <module>
#      12 ## Simple WordCloud
#      13 import matplotlib.pyplot as plt
# ---> 14 from wordcloud import WordCloud, STOPWORDS
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# <p> Lendo o arquivoCsv </p>

# %%
tweetsBrazillian = pd.read_csv("BrazillianTweet.csv", encoding = "ISO-8859-1")
print("Total records: ", len(tweetsBrazillian))
tweetsBrazillian.head()
# Out:
# Total records:  7990
#       status_id       user_id            created_at      screen_name  \
# 0  1.250570e+18  7.941206e+08  2020-04-16T00:00:12Z  josemarceloroch
# 1  1.250570e+18  1.049430e+18  2020-04-16T00:00:35Z      Pe_de_Jambo
# 2  1.250570e+18  6.914149e+07  2020-04-16T00:00:45Z   ThiagoRBrandao
# 3  1.250570e+18  1.625409e+08  2020-04-16T00:01:06Z      marceloblax
# 4  1.250580e+18  1.091420e+18  2020-04-16T00:01:52Z  CampoLimpoNotic
#
#                                                 text               source  \
# 0  Vendo a quantidade de dificuldades que princip...  Twitter for Android
# 1          Meu feed é resumido em: #BBB2O e #COVID19  Twitter for Android
# 2  "Seu José " madrugando na fila em Madureira(.....  Twitter for Android
# 3  #COVID19 #coronavirusbrasil https://t.co/4o13A...  Twitter for Android
# 4  #Saúde\nLevantamento de óbitos pelo coronavíru...  Twitter for Android
#
#    reply_to_status_id  reply_to_user_id reply_to_screen_name  is_quote  ...  \
# 0                 NaN               NaN                  NaN     False  ...
# 1                 NaN               NaN                  NaN     False  ...
# 2                 NaN               NaN                  NaN     False  ...
# 3                 NaN               NaN                  NaN     False  ...
# 4                 NaN               NaN                  NaN     False  ...
#
#    retweet_count  country_code         place_full_name place_type  \
# 0              0            BR    Caldas Novas, Brasil       city
# 1              0            BR        Salvador, Brazil       city
# 2              0            BR  Rio de Janeiro, Brazil       city
# 3              0            BR           Belém, Brazil       city
# 4              0            BR       Sao Paulo, Brazil       city
#
#   followers_count friends_count  account_lang  account_created_at  verified  \
# 0              81           396           NaN     8/31/2012 12:44     False
# 1              23            93           NaN     10/8/2018 19:57     False
# 2             857           937           NaN     8/26/2009 21:07     False
# 3             369           736           NaN      7/3/2010 21:21     False
# 4              34           165           NaN      2/1/2019 17:21     False
#
#   lang
# 0   pt
# 1   pt
# 2   pt
# 3  und
# 4   pt
#
# [5 rows x 22 columns]

# %%
#tweetsBrazillian.dtypes

# %%
tweetsBrazillian['friends_count'].max()
# Out:
# 49352

# %%
tweetsBrazillian['favourites_count'].max()
# Out:
# 352572

# %%
tweetsBrazillian['verified'].describe()
# Out:
# count      7990
# unique        2
# top       False
# freq       7697
# Name: verified, dtype: object

# %%
tweetsBrazillian['retweet_count'].describe()
# Out:
# count    7990.000000
# mean        1.248310
# std        11.820566
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max       672.000000
# Name: retweet_count, dtype: float64

# %%
tweetsBrazillian['followers_count'].describe()
# Out:
# count    7.990000e+03
# mean     5.446299e+03
# std      5.162496e+04
# min      0.000000e+00
# 25%      1.120000e+02
# 50%      4.030000e+02
# 75%      1.397000e+03
# max      1.412153e+06
# Name: followers_count, dtype: float64

# %% [markdown]
# <p> Eliminando colunas </p>

# %%
tweetsBrazillian.drop(['country_code', 'account_lang', 'status_id', 'user_id', 'account_created_at', 'reply_to_user_id', 'reply_to_status_id'], axis=1, inplace=True)

# %%
print("Total records: ", len(tweetsBrazillian))
tweetsBrazillian.head(2)
# Out:
# Total records:  7990
#       status_id       user_id            created_at      screen_name  \
# 0  1.250570e+18  7.941206e+08  2020-04-16T00:00:12Z  josemarceloroch
# 1  1.250570e+18  1.049430e+18  2020-04-16T00:00:35Z      Pe_de_Jambo
#
#                                                 text               source  \
# 0  Vendo a quantidade de dificuldades que princip...  Twitter for Android
# 1          Meu feed é resumido em: #BBB2O e #COVID19  Twitter for Android
#
#    reply_to_status_id  reply_to_user_id reply_to_screen_name  is_quote  ...  \
# 0                 NaN               NaN                  NaN     False  ...
# 1                 NaN               NaN                  NaN     False  ...
#
#    retweet_count  country_code       place_full_name place_type  \
# 0              0            BR  Caldas Novas, Brasil       city
# 1              0            BR      Salvador, Brazil       city
#
#   followers_count friends_count  account_lang  account_created_at  verified  \
# 0              81           396           NaN     8/31/2012 12:44     False
# 1              23            93           NaN     10/8/2018 19:57     False
#
#   lang
# 0   pt
# 1   pt
#
# [2 rows x 22 columns]

# %%
tweetsBrazillian['source'].describe()
# Out:
# count                    7990
# unique                     12
# top       Twitter for Android
# freq                     4163
# Name: source, dtype: object

# %% [markdown]
# <p> Agrupando as plataformas </p>

# %%
platforms_used = tweetsBrazillian.groupby('source')
platforms_used = platforms_used[['text']].count()
print("Total records: ", len(platforms_used))
platforms_used
# Out:
# Total records:  12
#                      text
# source
# Apphi                   1
# Echofon                 1
# Foursquare              3
# Hootsuite Inc.          1
# Instagram            1570
# Tweetbot for i?S       15
# Twitter Web Client      1
# Twitter for Android  4163
# Twitter for Mac         4
# Twitter for iPad       83
# Twitter for iPhone   2145
# WordPress.com           3

# %%
platforms_used.plot(kind='barh', stacked=False, figsize=[16,6], colormap='summer', title="Recursos mais usados")

# %%
place_used = tweetsBrazillian.sort(['place_full_name'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e7ff626e08ce> in <module>
# ----> 1 place_used = tweetsBrazillian.sort(['place_full_name'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
tweetsBrazillian['place_full_name'].unique()
# Out:
# array(['Caldas Novas, Brasil', 'Salvador, Brazil',
#        'Rio de Janeiro, Brazil', 'Belém, Brazil', 'Sao Paulo, Brazil',
#        'Anápolis, Brasil', 'Brasília, Brazil',
#        'Presidente Prudente, Brasil', 'Pirassununga, Brasil',
#        'Blumenau, Brasil', 'Santarém, Brasil', 'Porto Alegre, Brazil',
#        'Guarulhos, Brasil', 'Santos, Brasil', 'Puta que Pariu',
#        'Empresarial Domingos Ferreira', 'Alto Parnaíba, Brasil',
#        'Planalto, Brasil', 'Vila Velha, Brasil', 'Niterói, Brasil',
#        'Santana, Brasil', 'Curitiba, Brazil', 'São Luís, Brazil',
#        'São Félix do Araguaia, Brasil', 'Conde, Brasil',
#        'Aracaju, Brazil', 'Tiago Aquines Advogado', 'Catalão, Brasil',
#        'Guararapes, Brasil', 'Campina Grande, Brasil',
#        'São Caetano do Sul, Brasil', 'Parnamirim, Brasil',
#        'Cabo de Santo Agostinho, Brasil', 'São José de Ribamar, Brasil',
#        'Palmas, Brazil', 'Paulista, Brasil', 'Nova Iguaçu, Brasil',
#        'Recreio', 'Itapipoca, Brasil', 'Fortaleza, Brazil',
#        'Recife, Brazil', 'Tracuateua, Brasil', 'Caxias do Sul, Brasil',
#        'Santo André, Brasil', 'Maceió, Brazil', 'Belo Horizonte, Brazil',
#        'Osório, Brasil', 'Goiânia, Brazil', 'Boa Vista, Brazil',
#        'Vitória, Brazil', 'Guriri', 'Natal, Brazil', 'Oiapoque, Brasil',
#        'João Pessoa, Brazil', 'Gravataí, Brasil',
#        'Gramado Xavier, Brasil', 'Araruama, Brasil',
#        'Santana do Matos, Brasil', 'Jaboatão dos Guararapes, Brasil',
#        'São Sebastião da Boa Vista, Brasil', 'Morrinhos, Brasil',
#        'Manaus, Brazil', 'Shopping Centro Norte', 'Queimados, Brasil',
#        'São Bernardo do Campo, Brasil', 'Angra dos Reis, Brasil',
#        'Luziânia, Brasil', 'Camaragibe, Brasil', 'Caruaru, Brasil',
#        'Bauru, Brasil', 'Elói Mendes, Brasil',
#        'São Joaquim da Barra, Brasil', 'Patos de Minas, Brasil',
#        'Londrina, Brasil', 'Caetanópolis, Brasil', 'Urussanga, Brasil',
#        'Sorocaba, Brasil', 'Jardim Ouro Verde, Campinas',
#        'Olinda, Brasil', 'São Vicente, Brasil', 'Juiz de Fora, Brasil',
#        'Campinas, Brasil', 'Marabá, Brasil', 'Botucatu, Brasil',
#        'Maringá, Brasil', 'Alagoinhas, Brasil', 'São José, Brasil',
#        'Itaboraí, Brasil', 'Jaboticabal, Brasil', 'Serra Negra, Brasil',
#        'Barcarena, Brasil', 'Passo Fundo, Brasil', 'Araçatuba, Brasil',
#        'Cuiabá, Brazil', 'Colombo, Brasil', 'Leopoldina, Brasil',
#        'Praia Grande, Brasil', 'Limeira, Brasil',
#        'Praia da Barra da Tijuca', 'Condominio Nova Inhaúma',
#        'Carapicuíba, Brasil', 'Uberlândia, Brasil', 'Araguari, Brasil',
#        'Francisco Morato, Brasil', 'Florianópolis, Brazil',
#        'Arroio do Padre, Brasil', 'Pelotas, Brasil', 'Cotia, Brasil',
#        'Guarapari, Brasil', 'Rio Verde, Brasil', 'São Carlos, Brasil',
#        'E.M. Célia Sobreira', 'Ananindeua, Brasil', 'Jundiaí, Brasil',
#        'Osasco, Brasil',
#        'Universidade Federal do Rio Grande do Sul (UFRGS)',
#        'Guajará, Brasil', 'Maracanaú, Brasil', 'Santa Maria, Brasil',
#        'Foz do Iguaçu, Brasil', 'Cariacica, Brasil',
#        'Governador Valadares, Brasil', 'Sumidouro, Brasil',
#        'Campo Grande, Brazil', 'Ipatinga, Brasil', 'Pedra Branca, Brasil',
#        'Cabo Frio, Brasil', 'Montes Claros, Brasil', 'Betim, Brasil',
#        'Ceará-Mirim, Brasil', 'Marília, Brazil',
#        'Alfredo Marcondes, Brasil', 'São José do Rio Preto, Brasil',
#        'Estrela, Brasil', 'Petrolina, Brasil', 'Uberaba, Brasil',
#        'Novo Hamburgo, Brasil',
#        'Assembléia Legislativa do Estado de Minas Gerais',
#        'Petrópolis, Brasil', 'jardim leopoldina', 'Mutum, Brasil',
#        'Córrego do Ouro, Brasil', 'Piracicaba, Brasil',
#        'Aparecida de Goiânia, Brasil', 'Poá, Brasil', 'Alexânia, Brasil',
#        'Capão da Canoa, Brasil', 'Laranjeiras, Rio de Janeiro',
#        'Campos do Jordão, Brasil', 'Mossoró, Brasil', 'Macaé, Brasil',
#        'Nova Serrana, Brasil', 'Rio Branco, Brazil',
#        'Limoeiro do Norte, Brasil', 'São Leopoldo, Brasil',
#        'Taquaritinga, Brasil', 'Bento Gonçalves, Brasil',
#        'Mogi Guaçu, Brasil', 'Vargem Grande, Brasil',
#        'Teresópolis, Brasil', 'São João de Meriti, Brasil',
#        'Coronel Murta, Brasil', 'Duque de Caxias, Brasil',
#        'Curvelo, Brasil', 'Flores do Piauí, Brasil', 'Franca, Brasil',
#        '@oBarreiro - Capital Do MUNDO', 'Santa Rosa, Brasil',
#        'Rio das Pedras, Brasil', 'Feira de Santana, Brasil', 'Brazil',
#        'Santo Antônio, Brasil', 'Cantanhede, Brasil', 'Macapá, Brazil',
#        'Araguaína, Brasil', 'Manhuaçu, Brasil', 'Aracati, Brasil',
#        'Belo Jardim, Brasil', 'Nova Lima, Brasil',
#        'Cachoeiro de Itapemirim, Brasil', 'Iguaba Grande, Brasil',
#        'Boa Viagem, Recife', 'Maranhão, Brazil', 'Joinville, Brasil',
#        'Viseu, Brasil', 'Parintins, Brasil', 'Paranaguá, Brasil',
#        'Arcoverde, Brasil', 'São Gonçalo, Brasil', 'Teresina, Brazil',
#        'Barueri, Brasil', "Sant'Ana do Livramento, Brasil",
#        'Barreto, Niterói', 'Joanópolis, Brasil', 'Aliança, Brasil',
#        'São João del Rei, Brasil', 'Rio Grande do Sul, Brazil',
#        'Vilhena, Brasil', 'Parnaíba, Brasil', 'Paço do Lumiar, Brasil',
#        'Diadema, Brasil', 'Itacoatiara, Brasil', 'Itupeva, Brasil',
#        'Pindamonhangaba, Brasil', 'Poções, Brasil',
#        'Balneário Camboriú, Brasil', 'Quiririm, Taubaté',
#        'Barra Velha, Brasil', 'Vespasiano, Brasil',
#        'Lauro de Freitas, Brasil', 'Jerônimo Monteiro, Brasil',
#        'Armação dos Búzios, Brasil', 'Mogi das Cruzes, Brasil',
#        'Paraíba do Sul, Brasil', 'Mucajaí, Brasil', 'Camaçari, Brasil',
#        'Mineiros, Brasil', 'Guarujá, Brasil', 'Nazaré da Mata, Brasil',
#        'Porto Velho, Brazil', 'Magé, Brasil', 'Itabuna, Brasil',
#        'Itaporã, Brasil', 'Bacabal, Brasil', 'Canoas, Brasil',
#        'Sarandi, Brasil', 'Cristal, Brasil', 'Coronel Fabriciano, Brasil',
#        'Madureira, Rio de Janeiro', 'Rondônia, Brazil',
#        'Canguaretama, Brasil', 'Paraty, Brasil', 'Viçosa, Brasil',
#        'Barra Mansa, Brasil', 'Cataguases, Brasil',
#        'Vitória da Conquista, Brasil', 'Brusque, Brasil',
#        'Araraquara, Brasil', 'Salinas, Brasil', 'Espírito Santo, Brazil',
#        'Maricá, Brasil', 'Indaiatuba, Brasil', 'Grota', 'Barão, Brasil',
#        'Santa Cruz do Capibaribe, Brasil', 'Itajaí, Brasil',
#        'Cavalcante, Brasil', 'Alvorada, Brasil', 'Ribeirão Preto, Brasil',
#        'Louveira, Brasil', 'Mauá, Brasil', 'Pitanga, Brasil',
#        'São Cristóvão, Brasil', 'Mangaratiba, Brasil', 'Mirassol, Brasil',
#        'Penha, Brasil', 'Rio Pardo, Brasil', 'Cantagalo, Brasil',
#        'Guaratinguetá, Brasil', 'Munhoz de Melo, Brasil',
#        'São Mateus, Brasil', 'Morada Nova, Brasil', 'Valinhos, Brasil',
#        'Hospital Regional do Vale do Paraíba', 'Catanduva, Brasil',
#        'Serra, Brasil', 'Santa Luzia, Brasil', 'Palmital, Brasil',
#        'Pompéia, Brasil', 'Volta Redonda, Brasil', 'Abreu e Lima, Brasil',
#        'Itaguaí, Brasil', 'Guanambi, Brasil', 'Cachoeirinha, Brasil',
#        'Franco da Rocha, Brasil', 'Apucarana, Brasil',
#        'Secretaria Municipal de Saúde', 'Itatiba, Brasil',
#        'Imperatriz, Brasil', 'Inimutaba, Brasil',
#        'Campos dos Goytacazes, Brasil', 'Acará, Brasil',
#        'Ibiraçu, Brasil', 'Garanhuns, Brasil', 'Aracruz, Brasil',
#        'Várzea Grande, Brasil', 'Santana de Parnaíba, Brasil',
#        'Amapá, Brazil', 'UPA Rocinha', 'Caçapava, Brasil',
#        'Alerj - Assembleia Legislativa do Estado do Rio de Janeiro',
#        'Prefeitura Municipal de Aparecida de Goiânia',
#        'Americana, Brasil', 'Patos, Brasil', 'Paudalho, Brasil',
#        'Caieiras, Brasil', 'Taboão da Serra, Brasil', 'Miracema, Brasil',
#        'Serra Branca, Brasil', 'Vitória de Santo Antão, Brasil',
#        'São José do Egito, Brasil', 'Guarapuava, Brasil', 'Avaré, Brasil',
#        'Rio de Contas, Brasil', 'Caucaia, Brasil', 'Tupã, Brasil',
#        'Arujá, Brasil', 'Garça, Brasil', 'Rio Grande, Brasil',
#        'Juranda, Brasil', 'Santo Antônio de Pádua, Brasil',
#        'Gramado, Brasil', 'Pousada Sol e Mar',
#        'São José dos Campos, Brasil', 'Jacareí, Brasil',
#        'Poços de Caldas, Brasil', 'Curitiba', 'Piripiri, Brasil',
#        'Chuí, Brasil', 'Vitaminar Shop', 'Santa Fé do Sul, Brasil',
#        'Sete Lagoas, Brasil', '22 CICOM', 'Mesquita, Brasil',
#        'Resende, Brasil', 'Aeroporto de São Paulo / Congonhas (CGH)',
#        'Belford Roxo, Brasil', 'Juquitiba, Brasil',
#        'São José dos Pinhais, Brasil', 'Abaetetuba, Brasil',
#        'Palhoça, Brasil', 'Porto Belo, Brasil', 'Bebedouro, Brasil',
#        'Moreno, Brasil', 'Federal District, Brazil', 'São Borja',
#        'Contagem, Brasil', 'Itaperuna, Brasil', 'Pinheiral, Brasil',
#        'Cohatrac, São Luís', 'Alfenas, Brasil', 'Além Paraíba, Brasil',
#        'Águas Lindas de Goiás, Brasil', 'Pouso Alegre, Brasil',
#        'Uauá, Brasil', 'Apodi, Brasil', 'Esperança, Brasil',
#        'Parauapebas, Brasil', 'Monte Aprazível, Brasil',
#        'São Pedro da Aldeia, Brasil', 'Rio De Janeiro',
#        'Quirinópolis, Brasil', 'Itaituba, Brasil',
#        'Supermercados Guanabara', 'Atibaia, Brasil', 'Praça da Árvore',
#        'Campo Alegre', 'Perdizes, São Paulo', 'Tubarão, Brasil',
#        'Cabedelo, Brasil', 'Santa Catarina, Brazil', 'Favela',
#        'Mairiporã, Brasil', 'Sobral, Brasil',
#        'Luhana Pawlick - Alta Moda | Haute Couture',
#        'Marechal Floriano, Brasil', 'Ferreiros, Brasil',
#        'Guidoval, Brasil', 'Torres, Brasil', 'Caculé, Brasil',
#        'Iguaraci, Brasil', 'Paulínia, Brasil', 'Arraial do Cabo, Brasil',
#        'Hortolândia, Brasil', 'Arapiraca, Brasil', 'Xangri-Lá, Brasil',
#        'Embu, Brasil', 'Taquarituba, Brasil',
#        'Panificadora do Sr. Mário Venâncio',
#        'Fernando de Noronha, Brasil', 'Sapucaia do Sul, Brasil',
#        'Parque João Ramalho, Santo André', 'Pejuçara, Brasil',
#        'Minas Gerais, Brazil', 'Complexo do Alemão', 'Conquista, Brasil',
#        'Lajeado, Brasil', 'Caraguatatuba, Brasil', 'Uruguaiana, Brasil',
#        'Itatiaia, Brasil', 'Água Boa, Brasil',
#        'Divisa de São Vicente e Santos', 'Sumaré, Brasil',
#        'Guararema, Brasil', 'Coelho Neto, Brasil',
#        'Praia do Porto da Barra', 'Verdes Pracas',
#        'Bragança Paulista, Brasil', 'Santo Amaro, Brasil',
#        'Joaçaba, Brasil', 'Sinco.net', 'Coruripe, Brasil', 'Pará, Brazil',
#        'Tocantins, Brazil', 'Faro Beach Club', 'Araxá, Brasil',
#        'Capanema, Brasil', 'Uruará, Brasil', 'Arari, Brasil',
#        'Pacatuba, Brasil', 'Rio Quente, Brasil', 'Avenida Paulista',
#        'Cascavel, Brasil', 'São Roque, Brasil', 'Fim Do Mundo',
#        'Salto, Brasil', 'Taubaté, Brasil',
#        'Santo Antônio do Leverger, Brasil', 'Lugar Nenhum',
#        'Ernestina, Brasil', 'Carinhanha, Brasil',
#        'Jaraguá do Sul, Brasil', 'Itacuruba, Brasil', 'Ponta Negra',
#        'Ceará, Brazil', 'Ilha do Governador', 'Jequié, Brasil',
#        'Santiago, Brasil', 'Porto Seguro, Brasil', 'Frutal, Brasil',
#        'Cacoal, Brasil', 'Carazinho, Brasil', 'São Domingos, São Paulo',
#        'Ubá, Brasil', 'Santo Ângelo, Brasil', 'Mongaguá, Brasil',
#        'Conceição de Macabu, Brasil', 'Curitibanos, Brasil',
#        'Araripina, Brasil', 'Santa Maria de Jetibá, Brasil',
#        'Base Secreta Do Exercito Para Contatos Alienígenas',
#        'Ribeira do Pombal, Brasil', 'Teatro Eva Wilma',
#        'Rondonópolis, Brasil', 'Ibarama, Brasil', 'Chapadinha, Brasil',
#        'Itu, Brasil', 'Juazeiro do Norte, Brasil', 'Rio Bonito, Brasil',
#        'spiral chips - super do povo passaré', 'Mãe do Rio, Brasil',
#        'Caxias, Brasil', 'Uruará-PA', 'Dourados, Brasil', 'Brasil',
#        'Valparaíso de Goiás, Brasil', 'Carmo do Rio Claro, Brasil',
#        'Estádio Municipal Paulo Machado de Carvalho (Pacaembu)',
#        'Assaí Atacadista', 'Jardim Gramacho, Duque de Caxias',
#        'Maranguape, Brasil', 'Goianésia, Brasil', 'Caçador, Brasil',
#        'Araruna, Brasil', 'Divinópolis, Brasil', 'Avenida Oliveira Belo',
#        'Chapecó, Brasil', 'Linhares, Brasil', 'Cambé, Brasil',
#        'Tenente Portela, Brasil', 'Fernando Pedroza, Brasil',
#        'Areal, Brasil', 'Rocha, Rio de Janeiro',
#        'Residencial Monte Pascoal', 'Trairi, Brasil',
#        'Cristianópolis, Brasil', 'Tijuca, Rio de Janeiro',
#        'Nossa Senhora do Socorro, Brasil', 'Ponte Duarte Coelho',
#        'Crato, Brasil', 'Campo Magro, Brasil', 'Tangará da Serra, Brasil',
#        'Propriá, Brasil', 'Farroupilha, Brasil', 'Ribeirão Pires, Brasil',
#        'Naviraí, Brasil', 'Ribeirão das Neves, Brasil',
#        'São Sebastião, Brasil', 'Suzano, Brasil', 'Rio Negrinho, Brasil',
#        'Miranda, Brasil', 'Criciúma, Brasil', 'Inhuma, Brasil',
#        'Tapejara, Brasil', 'Guaçuí, Brasil', 'Lorena, Brasil',
#        'Governador Celso Ramos, Brasil', 'Tatuí, Brasil', 'Goiás, Brasil',
#        'Paraná, Brazil', 'Assis, Brasil', 'Monte Alegre, Brasil',
#        'Biguaçu, Brasil', 'Rio Claro, Brasil', 'Marialva, Brasil',
#        'Lontras, Brasil', 'Pau dos Ferros, Brasil', 'Seabra, Brasil',
#        'Santa Rita do Sapucaí, Brasil', 'Sinop, Brasil',
#        'Itapetininga, Brasil', 'Hospital Unimed-Rio', 'Viamão, Brasil',
#        'Farol de Itapuã', 'Erechim, Brasil',
#        'UFPE - Universidade Federal de Pernambuco', 'Araporã, Brasil',
#        'SuperVia - Estação Comendador Soares',
#        'Prefeitura de Ribeirão das Neves', 'Jaú, Brasil',
#        'Itatira, Brasil', 'Vacaria, Brasil', 'Catolé do Rocha, Brasil',
#        'Montanhas, Brasil', 'Mato Grosso do Sul, Brazil',
#        'Mosqueiro Pará', 'Jandaíra, Brasil', 'Barbacena, Brasil',
#        'Itapevi, Brasil', 'Nova Era, Brasil',
#        'Hospital Samaritano Paulista', 'Araguatins, Brasil',
#        'Maracanã, Rio de Janeiro', 'blumenau santa catarina',
#        'Ufrgs Campus Litoral Norte', 'Duas Barras, Brasil',
#        'Paranavaí, Brasil', 'Conselheiro Lafaiete, Brasil',
#        'Paracambi, Brasil', 'Ibicaraí, Brasil', 'Araras, Brasil',
#        'Vinhedo, Brasil', 'Luzilândia, Brasil', 'Belém, Brasil',
#        'Limoeiro, Brasil', 'Aguaí, Brasil', 'Ponta Grossa, Brasil',
#        'Montenegro, Brasil', 'Canela, Brasil', 'Valença, Brasil',
#        'Eusébio, Brasil', 'Ituiutaba, Brasil',
#        'Campo Grande, Rio de Janeiro', 'São Joaquim, Contagem',
#        'Iguape, Brasil', 'cemitério parque tarumã',
#        'Armazenna 1 - Logistic Center', 'Rio das Ostras, Brasil',
#        'Bayeux, Brasil', 'Tramandaí, Brasil', 'Japaratinga, Brasil',
#        'Peruíbe, Brasil', 'Votuporanga, Brasil', 'NEUROCOR',
#        'Viçosa do Ceará, Brasil', 'Bandeirantes, Brasil', 'Hopi Hari',
#        'Benevides, Brasil', 'Sítio Novo do Tocantins, Brasil',
#        'Votorantim, Brasil', 'Guaratuba, Brasil', 'Vila Rio, Guarulhos',
#        'Sacramento, Brasil', 'Guaporé, Brasil', 'Recreio, Brasil',
#        'Cajazeiras, Brasil', 'Barra Bonita, Brasil', 'Salvador',
#        'Sabará, Brasil', 'Cubatão, Brasil', 'Rianápolis, Brasil',
#        'Barra da Tijuca, Rio de Janeiro', 'Zaffari', 'Altamira, Brasil',
#        'Piraí, Brasil', 'Varginha, Brasil', 'Itabira, Brasil',
#        'Porto Nacional, Brasil', 'Centre, Porto Alegre',
#        'Extremoz, Brasil', 'Caraúbas, Brasil', 'Altos, Brasil',
#        'Águas Belas, Brasil', 'Santa Cruz do Sul, Brasil',
#        'Nilópolis, Brasil', 'Picos, Brasil', 'Apto May',
#        'São Sebastião do Paraíso, Brasil', 'Casimiro de Abreu, Brasil',
#        'Morro do Chapéu, Brasil',
#        'ALEPA - Assembleia Legislativa do Pará', 'Castelo, Brasil',
#        'Itanhaém, Brasil', 'Rafard, Brasil', 'Ilhabela, Brasil',
#        'Itabaiana, Brasil', 'Macau, Brasil', 'Maragogi, Brasil',
#        'Riacho das Almas, Brasil', 'Campos Belos, Brasil',
#        'Instituto Anisio Teixeira', 'Murici, Brasil',
#        'Nova Palmeira, Brasil', 'Tamandaré, Brasil', 'Itumbiara, Brasil',
#        'Andradina, Brasil', 'Arroio do Meio, Brasil',
#        'Felixlândia, Brasil', 'Arapongas, Brasil', 'Bom Jardim, Brasil',
#        'Feijó, Brasil', 'Lençóis Paulista, Brasil', 'Monteiro, Brasil',
#        'São Luís do Quitunde, Brasil', 'Acaraú, Brasil',
#        'Colatina, Brasil', 'Paraíso do Sul, Brasil',
#        'Carlos Barbosa, Brasil', 'Navegantes, Brasil',
#        'Rio Grande da Serra, Brasil', 'Itapoá, Brasil', 'Ilhota, Brasil',
#        'Supermercado Capitelli', 'Parque Primavera', 'Rio Largo, Brasil',
#        'Vila União, Fortaleza', 'Sítio do Laçador',
#        'Itapecerica da Serra, Brasil', 'Jarinu, Brasil',
#        'Fundação Oswaldo Cruz (Fiocruz)', 'Praia do Pepê', 'Porks',
#        'Alegrete, Brasil', "Dias d'Ávila, Brasil", 'Porciúncula, Brasil',
#        'Parobé, Brasil', 'Campo Largo, Brasil',
#        'Cornélio Procópio, Brasil', 'João Neiva, Brasil',
#        'Balsas, Brasil', 'Trindade, Brasil', 'Barra do Bugres, Brasil',
#        'Na puta que te pariu', 'Tabatinga, Brasil', 'Ipu, Brasil',
#        'Nova Friburgo, Brasil', 'Anastácio, Brasil',
#        'Ferraz de Vasconcelos, Brasil', 'Jaguariúna, Brasil',
#        'Visconde do Rio Branco, Brasil', 'Rio Grande do Norte, Brazil',
#        'Igarapé-Miri, Brasil', 'Ibirité, Brasil', 'Jacobina, Brasil',
#        'Ourém, Brasil', 'Amparo, Brasil', 'Pindaré-Mirim, Brasil',
#        'Vera Cruz, Brasil', 'Salesópolis, Brasil',
#        'Copacabana, Rio de Janeiro', 'Lagoa Santa, Brasil',
#        'João Monlevade, Brasil', 'Aquiraz, Brasil', 'Gameleira, Brasil',
#        'Bom Jesus do Itabapoana, Brasil', 'Sirinhaém, Brasil',
#        'Matão, Brasil', 'Grajaú, Brasil', 'Ilha da Conceição',
#        'Mariana Pimentel, Brasil', 'Catende, Brasil', 'Canindé, Brasil',
#        'Copacabana', 'Recreio dos Bandeirantes, Rio de Janeiro',
#        'Apuiarés', 'Tangará, Brasil', 'Registro, Brasil',
#        'Guaxupé, Brasil', 'Caraiva', 'Ulianópolis, Brasil',
#        'Pacajus, Brasil', 'Serrinha dos Pintos, Brasil', 'HomeOffice',
#        'Ariquemes, Brasil', 'Ubatuba, Brasil', 'Paranaíba, Brasil',
#        'Tucano, Brasil', 'Municipio De Santana', 'Vicência, Brasil',
#        'Mandaguari, Brasil', 'Carnaubal, Brasil', 'Laguna Carapã, Brasil',
#        'Petrópolis', 'Marau, Brasil', 'Ipojuca, Brasil',
#        'Rodrigues Alves, Brasil', 'Ourinhos, Brasil', 'Hotel Ibis Styles',
#        'Agrestina, Brasil', 'Araquari, Brasil',
#        'SMS - Secretaria Municipal da Saúde', 'Taquara, Brasil',
#        'Seropédica, Brasil', 'Bahia, Brazil', 'Cruz das Almas, Brasil',
#        'Paraíba, Brazil', 'Vila Formosa, São Paulo', 'Baturité, Brasil',
#        'Bonito, Brasil', 'Caconde, Brasil', 'Pinhais, Brasil',
#        'Pinheiros, Brasil', 'Madalena, Brasil', 'Parnarama, Brasil',
#        'Tamboril do Piauí, Brasil', 'Expresso Esgoto',
#        'Santa Adélia, Brasil', 'Garrafão do Norte, Brasil',
#        'Bertioga, Brasil', 'Campo Bom, Brasil', 'Lajinha, Brasil',
#        'Imbetiba', 'Barra de São Francisco, Brasil', 'Carbonita, Brasil',
#        'Itajubá, Brasil', 'Pombal, Brasil', 'Juazeiro, Brasil',
#        'Platina, Brasil', 'Minaçu, Brasil', 'São Borja, Brasil',
#        'Mirandópolis, Brasil', 'Igarassu, Brasil',
#        'União da Vitória, Brasil', 'Itajobi, Brasil',
#        'Pitangueiras, Brasil', 'Barra do Garças, Brasil',
#        'São Sebastião do Alto, Brasil', 'Timbó Grande, Brasil',
#        'Jacarezinho, Brasil', 'Piauí, Brazil', 'Almenara, Brasil',
#        'Bom Despacho, Brasil', 'Câmara Municipal de Campo Grande',
#        'Josenópolis, Brasil', 'Surubim, Brasil', 'Janga, Paulista',
#        'Fazenda Nova, Brasil', 'Alcântara, São Gonçalo',
#        'Comunidade do Dique', 'Irati, Brasil', 'Cordeiro, Brasil',
#        'Acopiara, Brasil', 'Hospital Estadual Getúlio Vargas',
#        'Residencial Bela Vista', 'Três Rios, Brasil', 'Sala do Castelo',
#        'Umuarama, Brasil', 'Craíbas, Brasil', 'Araçariguama, Brasil',
#        'Caém, Brasil', 'Lagarto', 'Ijuí, Brasil', 'Capinzal, Brasil',
#        'Intermares, Cabedelo', 'Guaraci, Brasil', 'Pindorama, Brasil',
#        'Fartura, Brasil', 'Castanhal, Brasil', 'Estreito, Brasil',
#        'Três Corações, Brasil', 'Telêmaco Borba, Brasil',
#        'Gaspar, Brasil', 'Barra do Ribeiro, Brasil', 'Saubara, Brasil',
#        'Itapema, Brasil', 'Freguesia do Ó, São Paulo',
#        'Praça Emídio Gama', 'Novo Aripuanã, Brasil',
#        'Embaixada do México', 'Em Casa', 'Canto do Buriti, Brasil',
#        'Adamantina, Brasil', 'Amazonas, Brazil', 'Caxias do Sul',
#        'Soure, Brasil', 'Maruim, Brasil', 'Santa Cruz, Brasil',
#        'Camocim, Brasil', 'Instituto de Medicina Tropical (IMT)',
#        'Bairro Morada Do Sol', 'Macaíba, Brasil', 'Mantena, Brasil',
#        'Encarnação De Salinas', 'Vista Shopping',
#        'Hospital Geral de Fortaleza (HGF)',
#        'Santo Antônio do Itambé, Brasil', 'Casa Do Virus',
#        'Lages, Brasil', 'Açai Mais Sabor', 'Cachambi, Rio de Janeiro',
#        'Ji-Paraná, Brasil', 'Roraima, Brazil', 'Araioses, Brasil'],
#       dtype=object)

# %%
tweetsBrazillian['retweet_count'].describe()
# Out:
# count    7990.000000
# mean        1.248310
# std        11.820566
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max       672.000000
# Name: retweet_count, dtype: float64

# %%
influencer = tweetsBrazillian[tweetsBrazillian['followers_count'] > 9999]
print("Total records: ", len(influencer))
influencer.head()
# Out:
# Total records:  576
#        status_id       user_id            created_at    screen_name  \
# 10  1.250580e+18  1.663759e+08  2020-04-16T00:07:25Z  PrefeituraBNU
# 11  1.250580e+18  3.048389e+09  2020-04-16T00:07:35Z    cgisaopaulo
# 45  1.250590e+18  3.477912e+07  2020-04-16T00:51:22Z        jnascim
# 49  1.250590e+18  3.477912e+07  2020-04-16T01:01:34Z        jnascim
# 59  1.250590e+18  9.921770e+17  2020-04-16T01:12:58Z        CmdoCMS
#
#                                                  text               source  \
# 10  Confira aqui o Boletim Coronavírus Blumenau at...   Twitter for iPhone
# 11  #StayHomeStaySafe \n#FightAgainstCoronavirus h...  Twitter for Android
# 45  #Covid19 - Casos  Mortes (15/4):\n???? 637359...   Twitter for iPhone
# 49  Mesmo com subnotificação, Brasil é 11° país do...   Twitter for iPhone
# 59  Porto Alegre/RS. Em 15 abril, 30 militares do ...   Twitter for iPhone
#
#     reply_to_status_id  reply_to_user_id reply_to_screen_name  is_quote  ...  \
# 10                 NaN               NaN                  NaN     False  ...
# 11                 NaN               NaN                  NaN      True  ...
# 45        1.249760e+18        34779125.0              jnascim     False  ...
# 49                 NaN               NaN                  NaN      True  ...
# 59                 NaN               NaN                  NaN     False  ...
#
#     retweet_count  country_code       place_full_name place_type  \
# 10              2            BR      Blumenau, Brasil       city
# 11              0            BR     Sao Paulo, Brazil       city
# 45              4            BR     Sao Paulo, Brazil       city
# 49              6            BR     Sao Paulo, Brazil       city
# 59             39            BR  Porto Alegre, Brazil       city
#
#    followers_count friends_count  account_lang  account_created_at  verified  \
# 10           15309           162           NaN     7/13/2010 21:37      True
# 11           10007           492           NaN      2/21/2015 0:03      True
# 45           40291          4300           NaN     4/23/2009 21:04      True
# 49           40291          4300           NaN     4/23/2009 21:04      True
# 59           93594            17           NaN      5/3/2018 20:01      True
#
#    lang
# 10   pt
# 11  und
# 45   ca
# 49   pt
# 59   pt
#
# [5 rows x 22 columns]

# %%
influencer_retweeted = influencer[influencer['is_retweet'] == False]

maiorRetweet = influencer_retweeted[influencer_retweeted['retweet_count'] == 672]

maiorRetweet = maiorRetweet.replace(r'\n',  ' ', regex=True)
print("Total records: ", len(maiorRetweet))
maiorRetweet
# Out:
# Total records:  1
#          status_id       user_id            created_at   screen_name  \
# 2411  1.251950e+18  2.474471e+09  2020-04-19T19:19:02Z  LemusteleSUR
#
#                                                    text              source  \
# 2411  -Avanza el #Covid19 y Bolsonaro va a un acto q...  Twitter for iPhone
#
#       reply_to_status_id  reply_to_user_id  reply_to_screen_name  is_quote  \
# 2411                 NaN               NaN                   NaN     False
#
#       ...  retweet_count  country_code    place_full_name place_type  \
# 2411  ...            672            BR  Sao Paulo, Brazil       city
#
#      followers_count friends_count  account_lang  account_created_at  \
# 2411           15373          2569           NaN      5/2/2014 16:51
#
#       verified lang
# 2411     False   es
#
# [1 rows x 22 columns]

# %%
pd.options.display.max_colwidth = 300

# %%
RETWEET = str(maiorRetweet.text)

# %% [markdown]
# <p> Recuperando o Tweets com mais retweet

# %%
RETWEET.replace('\\n', '')
# Out:
# '2411    -Avanza el #Covid19 y Bolsonaro va a un acto que aglomera apoyadores contra la cuarentena. -Pide cierre del congreso y corte suprema. -El viernes retiró reglas que exigían marcación y registro de armas. -Su hijo twittea bolsonaristas que festejan a disparos.  Cómo se cura esto? https://t.co/D3Lh...\nName: text, dtype: object'

# %%
#placesMoreTweets =
tweets_brasil = tweetsBrazillian.groupby('place_full_name')['text'].count().sort_values(ascending=False).head(20)


tweets_brasil.plot(kind='barh', stacked=False, figsize=[16,6], colormap='winter', title="Tweet Brasil")

# %%
tweets_in_sp = tweetsBrazillian[tweetsBrazillian['place_full_name'] == 'Sao Paulo, Brazil']
print("Total records: ", len(tweets_in_sp))
tweets_in_sp.head()
# Out:
# Total records:  1015
#        status_id       user_id            created_at      screen_name  \
# 4   1.250580e+18  1.091420e+18  2020-04-16T00:01:52Z  CampoLimpoNotic
# 6   1.250580e+18  4.872610e+09  2020-04-16T00:03:35Z      cadu_filmes
# 11  1.250580e+18  3.048389e+09  2020-04-16T00:07:35Z      cgisaopaulo
# 38  1.250580e+18  3.502630e+07  2020-04-16T00:39:56Z   Mo_Americanoid
# 45  1.250590e+18  3.477912e+07  2020-04-16T00:51:22Z          jnascim
#
#                                                                                                                                                                                                                                                                                                            text  \
# 4      #Saúde\nLevantamento de óbitos pelo coronavírus de acordo com cada subprefeitura.\nFicar em casa é a medida mais importante para evitar que o Covid-19 se espalhe.\n\n#CampoLimpoZonaSul #ZonaSul #ZonaSulNoticias #CampoLimpo #CampoLimpoNotícias #Covid19 #CoronavírusSãoPaulo https://t.co/MCo7bl4mzJ
# 6                                                                                                            Campanha 3 - Juntos contra o Coronavírus!\n.\n#fiqueemcasa #juntoscontraocoronavirus #novocoronavirus #coronavirus #covid19 #cadufilmes #caduragem https://t.co/rBB06s9LaQ https://t.co/xoCZ7xfrVz
# 11                                                                                                                                                                                                                                         #StayHomeStaySafe \n#FightAgainstCoronavirus https://t.co/Ub605F5xAX
# 38                                                                                                                                                   In times of coronavirus weve got to be united - one for all, all for one #cats #gatos #covid19 #quarantine ?? @ São Paulo, Brazil https://t.co/VUNLYsK2fI
# 45  #Covid19 - Casos  Mortes (15/4):\n???? 637359  28364\n???? 180659  18812\n???? 165155  21645\n???? 134753  3804\n???? 134582  17188\n???? 99489  12894\n???? 83356  3346\n???? 76389  4777\n???? 69392  1518\n???? 33573  4440\n???? 28610  1757\n???? 28316  3145\n?? 2060927  134354 htt...
#
#                  source  reply_to_status_id  reply_to_user_id  \
# 4   Twitter for Android                 NaN               NaN
# 6   Twitter for Android                 NaN               NaN
# 11  Twitter for Android                 NaN               NaN
# 38            Instagram                 NaN               NaN
# 45   Twitter for iPhone        1.249760e+18        34779125.0
#
#    reply_to_screen_name  is_quote  ...  retweet_count  country_code  \
# 4                   NaN     False  ...              0            BR
# 6                   NaN     False  ...              1            BR
# 11                  NaN      True  ...              0            BR
# 38                  NaN     False  ...              0            BR
# 45              jnascim     False  ...              4            BR
#
#       place_full_name place_type followers_count friends_count  account_lang  \
# 4   Sao Paulo, Brazil       city              34           165           NaN
# 6   Sao Paulo, Brazil       city              24            60           NaN
# 11  Sao Paulo, Brazil       city           10007           492           NaN
# 38  Sao Paulo, Brazil       city            2340           990           NaN
# 45  Sao Paulo, Brazil       city           40291          4300           NaN
#
#     account_created_at  verified lang
# 4       2/1/2019 17:21     False   pt
# 6       2/2/2016 18:38     False   pt
# 11      2/21/2015 0:03      True  und
# 38     4/24/2009 17:15     False   en
# 45     4/23/2009 21:04      True   ca
#
# [5 rows x 22 columns]

# %% [markdown]
# <h4> Entendendo os tweets em SP </h4>

# %%
words = []
words_String=''
for text in tweets_in_sp['text']:
    words.append(text.replace('\n', ' '))
    
for item in words:
    words_String = words_String + item
    
words_String

# %%
word_tokens = word_tokenize(words_String)
len(word_tokens)
# Out:
# 33872

# %%
tk = WhitespaceTokenizer()
wordHashTags = tk.tokenize(words_String)
len(wordHashTags)
#wordHashTags
# Out:
# 22714

# %%
fdist = FreqDist()
for word in wordHashTags:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({'de': 668, 'e': 419, 'o': 416, '#covid19': 414, 'a': 396, '#coronavirus': 379, 'que': 339, 'em': 333, 'do': 286, 'da': 212, ...})

# %%
type(fdist)
# Out:
# nltk.probability.FreqDist

# %%
df_word = pd.DataFrame(list(fdist.items()), columns = ["Word","Frequency"])
print("Total records: ", len(df_word))
df_word.head()
# Out:
# Total records:  8366
#            Word  Frequency
# 0        #saúde          7
# 1  levantamento          1
# 2            de        668
# 3        óbitos         10
# 4          pelo         35

# %%
fdist_text = fdist.most_common(100)
type(fdist_text)
fdist_text
# Out:
# [('de', 668),
#  ('e', 419),
#  ('o', 416),
#  ('#covid19', 414),
#  ('a', 396),
#  ('#coronavirus', 379),
#  ('que', 339),
#  ('em', 333),
#  ('do', 286),
#  ('da', 212),
#  ('no', 196),
#  ('com', 161),
#  ('não', 154),
#  ('para', 152),
#  ('é', 151),
#  ('na', 136),
#  ('se', 134),
#  ('#covid_19', 134),
#  ('.', 127),
#  ('#quarentena', 114),
#  ('são', 113),
#  ('por', 111),
#  ('??', 110),
#  ('um', 104),
#  ('mais', 93),
#  ('os', 93),
#  ('#fiqueemcasa', 92),
#  ('uma', 84),
#  ('#coronavírus', 78),
#  ('#pandemia', 73),
#  ('paulo,', 70),
#  ('as', 70),
#  ('brazil', 66),
#  ('????', 64),
#  ('ao', 62),
#  ('brasil', 60),
#  ('sobre', 56),
#  ('está', 56),
#  ('dos', 52),
#  ('#ficaemcasa', 51),
#  ('tem', 48),
#  ('como', 46),
#  ('#covid', 43),
#  ('pra', 42),
#  ('já', 41),
#  ('vai', 39),
#  ('pessoas', 39),
#  ('contra', 38),
#  ('mortes', 37),
#  ('pandemia', 36),
#  ('você', 36),
#  ('pelo', 35),
#  ('-', 35),
#  ('#bolsonarogenocida', 35),
#  ('nos', 35),
#  ('#covid?19', 35),
#  ('#corona', 35),
#  ('ser', 34),
#  ('#coronavirusbrasil', 34),
#  ('eu', 33),
#  ('\x95', 32),
#  ('mundo', 32),
#  ('quem', 32),
#  ('isso', 32),
#  ('/', 32),
#  ('saúde', 31),
#  ('só', 31),
#  ('sem', 31),
#  ('estão', 30),
#  ('dia', 30),
#  ('ou', 30),
#  ('#bolsonaro', 29),
#  ('essa', 29),
#  ('até', 29),
#  ('1', 28),
#  ('#sp1', 28),
#  ('sentido', 28),
#  ('to', 27),
#  ('mas', 27),
#  ('#sp2', 27),
#  ('#forabolsonaro', 26),
#  ('das', 26),
#  ('#brasil', 26),
#  ('ainda', 26),
#  ('#covi?d19', 26),
#  ('meu', 26),
#  ('paulo', 26),
#  ('mesmo', 25),
#  ('sua', 25),
#  ('the', 25),
#  ('metrô', 25),
#  ('#bdsp', 25),
#  ('linha', 25),
#  ('casos', 24),
#  ('casa', 23),
#  ('q', 23),
#  ('muito', 23),
#  ('#isolamentosocial', 23),
#  ('me', 23),
#  ('??????', 22)]

# %%
tokensBlank = blankline_tokenize(words_String)
len(tokensBlank)
# Out:
# 1

# %%
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = "Palavras mais usadas"):
    
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=200,
        max_font_size=40, 
        scale=2,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(fdist_text)
